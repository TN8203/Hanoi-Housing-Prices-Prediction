# %%
import numpy as np
import pandas as pd
import csv
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime as dt
import statistics
import math
import re

import warnings 
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Data Cleaning

# %%
# Load data
dtset = pd.read_csv("../../Hanoi-Housing-Prices-Prediction/Dataset/data_chung cu.csv")
dtset_columns = dtset.columns.tolist()
print("+ Shape: ", dtset.shape) # (Number of Lines, Number of Columns)
print("+ Column: ", dtset_columns) # Name the attribute columns.
dtset.info()
# Out:
# + Shape:  (15145, 17)
# + Column:  ['Tiêu đề', 'Dự án', 'Khu vực', 'Ngày đăng', 'Ngày hết hạn', 'Loại tin', 'Mã tin', 'Người đăng', 'Thông tin mô tả', 'Diện tích', 'Mức giá', 'Hướng nhà', 'Hướng ban công', 'Số phòng ngủ', 'Số toilet', 'Pháp lý', 'Nội thất']
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15145 entries, 0 to 15144
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Tiêu đề          15145 non-null  object
#  1   Dự án            15145 non-null  object
#  2   Khu vực          15145 non-null  object
#  3   Ngày đăng        15145 non-null  object
#  4   Ngày hết hạn     15145 non-null  object
#  5   Loại tin         15145 non-null  object
#  6   Mã tin           15145 non-null  int64
#  7   Người đăng       15145 non-null  object
#  8   Thông tin mô tả  15145 non-null  object
#  9   Diện tích        15145 non-null  object
#  10  Mức giá          15145 non-null  object
#  11  Hướng nhà        7516 non-null   object
#  12  Hướng ban công   8215 non-null   object
#  13  Số phòng ngủ     14701 non-null  object
#  14  Số toilet        13960 non-null  object
#  15  Pháp lý          12091 non-null  object
#  16  Nội thất         11186 non-null  object
# dtypes: int64(1), object(16)
# memory usage: 2.0+ MB

# %%
dtset.head(3)
# Out:
#                                              Tiêu đề  \
# 0  Chính chủ bán căn hoa hậu view thoáng tầng tru...
# 1                    Bán căn hộ CT5 Văn Khê, Hà Đông
# 2  Cần tiền bán nhanh căn hộ cao cấp tòa Diamond ...
#
#                         Dự án  \
# 0         Dự án Golden Palace
# 1           Dự án CT5 Văn Khê
# 2  Dự án Diamond Flower Tower
#
#                                              Khu vực   Ngày đăng Ngày hết hạn  \
# 0  đường Mễ Trì, Phường Mễ Trì, Nam Từ Liêm, Hà Nội.  26/02/2024   07/03/2024
# 1                     Phường La Khê, Hà Đông, Hà Nội  26/02/2024   07/03/2024
# 2  Phố Hoàng Đạo Thúy, Phường Nhân Chính, Thanh X...  21/02/2024   02/03/2024
#
#      Loại tin    Mã tin      Người đăng  \
# 0  Tin thường  37587338  Phạm Quang Huy
# 1  Tin thường  39014297  Little Bigbang
# 2  Tin thường  39135117         Em Thúy
#
#                                      Thông tin mô tả Diện tích      Mức giá  \
# 0  Chính chủ bán căn hoa hậu view thoáng tầng tru...    128 m²  35 triệu/m²
# 1  Bán căn hộ CT5A, Văn Khê, Hà Đông.\n- Diện tíc...     82 m²      2,65 tỷ
# 2  - Chính chủ cần tiền đầu tư nhờ bán gấp căn hộ...    115 m²  55 triệu/m²
#
#    Hướng nhà Hướng ban công Số phòng ngủ Số toilet         Pháp lý Nội thất
# 0  Tây - Bắc     Đông - Nam      3 phòng   2 phòng             NaN      NaN
# 1  Tây - Bắc     Đông - Nam      2 phòng   2 phòng         Sổ hồng   Đầy đủ
# 2        Nam            NaN      3 phòng   2 phòng  Sổ đỏ/ Sổ hồng   Đầy đủ

# %%
dtset.tail(3)
# Out:
#                                                  Tiêu đề  \
# 15142  Bán căn 3 ngủ - 2 ban công 100m2 Sunshine Rive...
# 15143  Bán CC Duyên Hải 16B Nguyễn Thái Học 120m2, 3 ...
# 15144  Giá tốt cho căn 1+1 diện tích 43m2 nội thất đẹ...
#
#                                    Dự án  \
# 15142           Dự án Sunshine Riverside
# 15143          Dự án 16B Nguyễn Thái Học
# 15144  Dự án Vinhomes Ocean Park Gia Lâm
#
#                                                  Khu vực   Ngày đăng  \
# 15142                  Phường Phú Thượng, Tây Hồ, Hà Nội  10/03/2024
# 15143  Đường Nguyễn Thái Học, Phường Yết Kiêu, Hà Đôn...  29/02/2024
# 15144                       Xã Dương Xá, Gia Lâm, Hà Nội  23/02/2024
#
#       Ngày hết hạn    Loại tin    Mã tin Người đăng  \
# 15142   20/03/2024  Tin thường  39173497      Lý Vt
# 15143   10/03/2024  Tin thường  39192082       Tuấn
# 15144   04/03/2024  Tin thường  39152075    Lưu Yến
#
#                                          Thông tin mô tả Diện tích  Mức giá  \
# 15142  Cần bán căn hộ 3 ngủ Sunshine Riverside Tây Hồ...    100 m²   5,5 tỷ
# 15143  Đã mua liền kề biệt thự, cần bán chung cư Duyê...    120 m²   3,3 tỷ
# 15144  Thay đổi nhu cầu nên chính chủ cần chuyển nhượ...     43 m²  1,55 tỷ
#
#         Hướng nhà Hướng ban công Số phòng ngủ Số toilet           Pháp lý  \
# 15142         NaN           Đông      3 phòng   3 phòng    Sổ đỏ/ Sổ hồng
# 15143   Tây - Bắc     Đông - Nam      3 phòng       NaN  Hợp đồng mua bán
# 15144  Đông - Bắc      Tây - Nam      1 phòng   1 phòng             Sổ đỏ
#
#                                               Nội thất
# 15142                                           Cơ bản
# 15143                                           Đầy đủ
# 15144  Full đồ nội thất liền tường: Giường tủ, bếp,...

# %%
display(dtset[6:10])
# Out:
#                                              Tiêu đề                  Dự án  \
# 6  Chuyển nhượng căn hộ 3PN chỉ 4tỷ5 bao phí Suns...  Dự án Sunshine Garden
# 7  Cần bán căn chung cư Park Home 120,4m2 góc ngã...    Dự án The Park Home
# 8  Bán quỹ căn ngoại giao cuối cùng dự án The Par...    Dự án The Park Home
# 9  Bán gấp - bán chung cư CT1 Đại học Kinh Tế Quố...       Đường Giải Phóng
#
#                                              Khu vực   Ngày đăng Ngày hết hạn  \
# 6  Đường Dương Văn Bé, Phường Vĩnh Tuy, Hai Bà T...  18/02/2024   19/03/2024
# 7  Đường Thành Thái, Phường Dịch Vọng, Cầu Giấy, ...  29/02/2024   10/03/2024
# 8  Đường Thành Thái, Phường Dịch Vọng, Cầu Giấy, ...  19/02/2024   05/03/2024
# 9                Phường Tương Mai, Hoàng Mai, Hà Nội  26/02/2024   07/03/2024
#
#      Loại tin    Mã tin       Người đăng  \
# 6  Tin thường  38989881     Cao Tuấn Anh
# 7  Tin thường  39200019    Bùi Xuân Giáp
# 8  Tin thường  37662145   Nguyễn Đức Hoà
# 9  Tin thường  35712237  Hưng Chủ Đầu Tư
#
#                                      Thông tin mô tả Diện tích     Mức giá  \
# 6  Do không có nhu cầu sử dụng chính chủ rao bán ...     95 m²      4,5 tỷ
# 7  Cần bán căn chung cư 120,4m² góc ngã tư Thành ...  120,4 m²  Thỏa thuận
# 8  Quỹ căn ngoại giao cuối cùng dự án The Park Ho...    120 m²      6,7 tỷ
# 9  Chủ đầu tư bán trực tiếp căn hộ CT1 Đại học Ki...     56 m²   660 triệu
#
#     Hướng nhà Hướng ban công Số phòng ngủ Số toilet         Pháp lý  \
# 6         NaN            NaN      3 phòng   2 phòng  Sổ đỏ/ Sổ hồng
# 7  Đông - Nam     Đông - Nam      3 phòng   2 phòng  Sổ đỏ/ Sổ hồng
# 8         NaN            NaN      3 phòng   2 phòng  Sổ đỏ/ Sổ hồng
# 9         NaN            NaN      2 phòng   2 phòng  Sổ đỏ/ Sổ hồng
#
#                                             Nội thất
# 6                                             Cơ bản
# 7                                             Đầy đủ
# 8  Cơ bản, điều hòa âm trần, thiết bị vệ sinh, tủ...
# 9                       Nội thất đầy đủ - về ở luôn.

# %%
# Display data by column
dtset.loc[:2, dtset_columns[0:3]]
# Out:
#                                              Tiêu đề  \
# 0  Chính chủ bán căn hoa hậu view thoáng tầng tru...
# 1                    Bán căn hộ CT5 Văn Khê, Hà Đông
# 2  Cần tiền bán nhanh căn hộ cao cấp tòa Diamond ...
#
#                         Dự án  \
# 0         Dự án Golden Palace
# 1           Dự án CT5 Văn Khê
# 2  Dự án Diamond Flower Tower
#
#                                              Khu vực
# 0  đường Mễ Trì, Phường Mễ Trì, Nam Từ Liêm, Hà Nội.
# 1                     Phường La Khê, Hà Đông, Hà Nội
# 2  Phố Hoàng Đạo Thúy, Phường Nhân Chính, Thanh X...

# %%
print("Loại tin:", dtset[dtset_columns[5]].unique())
dtset.loc[:2, dtset_columns[3:9]]
# Out:
# Loại tin: ['Tin thường' 'Tin VIP Bạc' 'Tin VIP Kim Cương' 'Tin VIP Vàng']
#     Ngày đăng Ngày hết hạn    Loại tin    Mã tin      Người đăng  \
# 0  26/02/2024   07/03/2024  Tin thường  37587338  Phạm Quang Huy
# 1  26/02/2024   07/03/2024  Tin thường  39014297  Little Bigbang
# 2  21/02/2024   02/03/2024  Tin thường  39135117         Em Thúy
#
#                                      Thông tin mô tả
# 0  Chính chủ bán căn hoa hậu view thoáng tầng tru...
# 1  Bán căn hộ CT5A, Văn Khê, Hà Đông.\n- Diện tíc...
# 2  - Chính chủ cần tiền đầu tư nhờ bán gấp căn hộ...

# %%
dtset.loc[:2, dtset_columns[9:10]]
# Out:
#   Diện tích
# 0    128 m²
# 1     82 m²
# 2    115 m²

# %%
print("Hướng nhà:", dtset[dtset_columns[11]].unique())
print("Hướng ban công:", dtset[dtset_columns[12]].unique())
# Out:
# Hướng nhà: ['Tây - Bắc' 'Nam' nan 'Đông - Nam' 'Tây - Nam' 'Đông' 'Đông - Bắc' 'Bắc'
#  'Tây']
# Hướng ban công: ['Đông - Nam' nan 'Tây - Bắc' 'Đông - Bắc' 'Bắc' 'Tây - Nam' 'Nam' 'Đông'
#  'Tây']

# %%
dtset.loc[:2, dtset_columns[13:17]]
# Out:
#   Số phòng ngủ Số toilet         Pháp lý Nội thất
# 0      3 phòng   2 phòng             NaN      NaN
# 1      2 phòng   2 phòng         Sổ hồng   Đầy đủ
# 2      3 phòng   2 phòng  Sổ đỏ/ Sổ hồng   Đầy đủ

# %%
print("Pháp lý:", dtset[dtset_columns[15]].unique())
# Out:
# Pháp lý: [nan 'Sổ hồng' 'Sổ đỏ/ Sổ hồng' 'Sổ đỏ' 'Sổ đỏ.' 'Hợp đồng mua bán'
#  'Sổ đỏ/ Sổ hồng.' 'Sổ hồng cầm tay' 'Đã có sổ.' 'Đang chờ sổ.'
#  'Nội thất liền tường đầy đủ' 'Sổ đỏ chính chủ, sẵn sàng giao dịch.'
#  'Đã có sổ đỏ.' 'Sổ đỏ chính chủ.'
#  'Sổ đỏ PTCC, giấy phép XD, hợp đồng mua bán căn hộ, cam kết tách sổ.'
#  'Sổ hồng lâu dài' 'Đã có sổ đỏ' 'Đang chờ sổ' 'Sẵn sổ đỏ'
#  'Đã có sổ lâu dài' 'Hợp đồng mua bán.' 'HĐMB.' 'Đã có sổ' 'Sổ hồng.'
#  'Có sổ.' 'Đã có sổ, sẵn sàng giao dịch' 'Đầy đủ'
#  'Sổ chung, pháp lý mua bán chuẩn chỉ, sở hữu chính chủ.'
#  'Sổ đỏ vĩnh viễn' 'Pháp lý đầy đủ, hỗ trợ vay ngân hàng.'
#  'Đã có sổ đỏ tổng.' 'Sổ đỏ chính chủ' 'Sổ đỏ lâu dài.' 'Sổ lâu dài.'
#  'Sổ đầy đủ' 'Đang chờ nhận sổ.' 'Đã có sổ hồng lâu dài' 'Sổ đỏ bàn giao'
#  'SĐCC.' 'Sổ đỏ toà nhà đầy đủ, CĐT là công ty' 'Sổ đỏ đầy đủ.'
#  'Đã có sổ đỏ chính chủ.' 'Sổ đỏ lâu dài' 'HĐMB' 'Sổ đỏ chờ giao dịch'
#  'Nhà có sổ đỏ.' 'Có sổ đỏ' 'Có sổ đỏ.' 'Đã có sổ ,sẵn giao dịch'
#  'Sổ hồng chính chủ.' 'Đầy đủ, minh bạch,' 'Đã có sổ đỏ tổng'
#  'Pháp lý đầy đủ , sổ đỏ cầm tay sẵn sàng giao dịch' 'Đầy đủ đã có sổ'
#  'Có sổ' 'Sổ hồng vĩnh viễn' 'Sổ đỏ chính xủ.h' 'Sổ Hồng lâu dài'
#  'Sổ đỏ cầm tay' 'Sổ hồng sở hữu lâu dài' 'Sổ chính chủ' 'Sổ lâu dài'
#  'Hợp đồng' 'Nhà đã có sổ hồng.' 'HDMB 50 năm' 'Sổ đỏ chính chủ lâu dài'
#  'Đã có sổ sở hữu lâu dài.' 'Vào ở làm sổ luôn' 'Sổ vĩnh viễn'
#  'Đã có sổ đỏ, sổ đỏ chính chủ' 'HDMB' 'Sổ'
#  'Pháp lý minh bạch, khách hàng có nhu cầu xem pháp lý dự án xem trực tiếp tại văn phòng chủ đầu tư. Khách hàng kí trực tiếp hợp đồng mua bán nhà hình thành trong tương lai với CĐT.'
#  'Sổ đỏ trao tay'
#  'Pháp lý dự án minh bạch, khách hàng xem trực tiếp hồ sơ pháp lý tại văn phòng Chủ Đầu Tư. Khách hàng mua bán bằng hình thức kí Hợp Đồng Mua Bán nhà ở hình thành trong tương lai trực tiếp với CĐT.'
#  'Pháp lý rõ ràng' 'Sổ hồng lâu dài.'
#  'Căn góc rộng nhất sở hữu tới 3 mặt thoáng, ban công Đông nam cực mát tại chung cư cao cấp BRG Lê Văn Lương vị trí thuận tiện góc ngã tư Lê Văn Lương giao Hoàng Đạo Thúy. Diện tích thông thủy 201m thiết kế 4 phòng ngủ rộng, không gian bếp tách biệt, tất'
#  'Sổ đỏ chinh chủ' '- Sổ đỏ chính chủ.' 'Sổ đỏ cất két' 'Sang tên vi bằng'
#  'Sổ đỏ CC.' 'Sổ đỏ chính chủ - pháp lý rõ ràng.' 'Chính chủ'
#  'SỔ ĐỎ CHÍNH CHỦ.' 'Sổ đỏ cất két sẵn sàng giao dịch'
#  'Sổ đỏ chính chủ giao dịch ngay.' 'GIẤY TỜ SỔ ĐỎ ĐẦY ĐỦ'
#  'Sổ đỏ chính chủ sẵn sàng giao dịch' 'Hợp đồng mua bán và sổ đỏ'
#  'Sổ hồng/ sổ đỏ' 'Sẵn sổi' 'Chờ lấy sổ' 'SĐCC'
#  'Nhà mới bàn giao, đang chờ sổ.' 'Đã có sổ đỏ, không vay ngân hàng'
#  'Sổ sách đầy đủ' 'Đang làm sổ' 'Có sổ, sổ chính chủ sẵn sàng giao dịch.'
#  'Đã có sổ đỏ sẵn sàng giao dịch' 'Sổ đỏ/ Sổ hồ'
#  'Mua bán vi bằng, sổ hồng chung cả tòa nhà' 'Sổ.' 'Đã có' 'Có sổ đỏ rồi.'
#  'Sổ Đỏ' 'Pháp lý rõ ràng - CĐT uy tín' 'Sổ đỏ nét căng.'
#  'Sổ đỏ/ Sổ hồng, căn hộ 50 năm.' 'Đầy đủ sẵn sàng giao dịch'
#  'Đã có sổ đỏ cất ở két.' 'KÝ MỚI TRỰC TIẾP CĐT' 'Vi Bằng' 'Đã có sổ hồng'
#  'Giấy tờ pháp lý chuẩn'
#  'Giấy phép xây dựng, hợp đồng mua bán, thông báo đủ điều kiện mở bán,...'
#  'Sổ hồng vĩnh viễn.' 'Sổ đỏ chính chủ, pháp lý rõ ràng'
#  'Đã có sổ, hỗ trợ vay ngân hàng.' 'Chưa sổ.' 'Sổ đỏ đã có sẵn.'
#  'Đã có sổ đỏ sẵn giao dịch cọc luôn'
#  'Sổ đỏ chính chủ, sẵn sàng giao dịch ngay.' 'Sổ sẵn giao dịch'
#  'Hợp đồng mua bán, sở hữu lâu dài' 'Sổ đỏ vĩnh viễn.'
#  'Toà nhà đầy đủ sổ đỏ, GPXD, PCCC' 'Ký HĐMB' 'SĐCC ss Gdich'
#  'Đã có sổ hồng.' 'Đã có sổ đỏ cất két' 'Sổ đỏ,' 'Có sổ lâu dài'
#  'Đã có sổ, sổ cất két sẵn sàng giao dịch' 'Có sổ đầy đủ' 'Đã có sổ'
#  'Hợp đồng góp vốn' 'Đã sổ hồng' 'HĐMB đã đóng full tiền cho CĐT chờ sổ.'
#  'Sỏ đỏ']

# %% [markdown]
# ### Dealing with Duplicate lines

# %%
# Check home listing templates with the same "Mã tin":
matin_duplicate_df = dtset[dtset["Mã tin"].duplicated()]
print("Number of lines duplicated 'Mã tin' =", len(matin_duplicate_df))
matin_duplicate_df[31:33]
# Out:
# Number of lines duplicated 'Mã tin' = 180
#                                                 Tiêu đề            Dự án  \
# 4721  Cần bán căn 2pn, 2vs toà thương mại cc The Ves...  Dự án The Vesta
# 4782  Cần bán căn 2pn, 2vs toà thương mại cc The Ves...  Dự án The Vesta
#
#                               Khu vực   Ngày đăng Ngày hết hạn    Loại tin  \
# 4721  Phường Phú Lãm, Hà Đông, Hà Nội  23/02/2024   04/03/2024  Tin thường
# 4782  Phường Phú Lãm, Hà Đông, Hà Nội  23/02/2024   04/03/2024  Tin thường
#
#         Mã tin  Người đăng                                    Thông tin mô tả  \
# 4721  39051171  Hiền Alina  Cần bán căn hộ 2pn, 2vs chung cư The Vesta Phú...
# 4782  39051171  Hiền Alina  Cần bán căn hộ 2pn, 2vs chung cư The Vesta Phú...
#
#      Diện tích  Mức giá Hướng nhà Hướng ban công Số phòng ngủ Số toilet  \
# 4721     57 m²  2,15 tỷ       Nam            Bắc      2 phòng   2 phòng
# 4782     57 m²  2,15 tỷ       Nam            Bắc      2 phòng   2 phòng
#
#      Pháp lý Nội thất
# 4721     NaN   Đầy đủ
# 4782     NaN   Đầy đủ

# %%
# Delete duplicates
# Check if any data is duplicated
duplicate_df = dtset[dtset.duplicated()] # Save duplicate lines to separate dataframe
duplicate_df = duplicate_df.reset_index() # Reset the index of the new dataframe.
#display(duplicate_df)
print("Number of duplicate lines =", len(duplicate_df))
# Out:
# Number of duplicate lines = 155

# %%
# Example of all lines with duplicate "Khu vực" of a data sample
diachivalue = duplicate_df["Khu vực"].iloc[0] # Get the value of the "Khu vực" column from the row at index 0 in the dataframe containing duplicates
print("Data Type =", type(diachivalue)) # This value has a String data type
dtset.loc[dtset["Khu vực"] == diachivalue] # Return to the original dataset, display all rows that are duplicates
# Out:
# Data Type = <class 'str'>
#                                                  Tiêu đề            Dự án  \
# 27     Cần bán căn 2pn, 2vs toà thương mại cc The Ves...  Dự án The Vesta
# 86     Cần bán căn 2pn, 2vs toà thương mại cc The Ves...  Dự án The Vesta
# 202    Cần bán căn 2pn, 2vs toà thương mại cc The Ves...  Dự án The Vesta
# 478    Giảm sâu: Duy nhất căn 59m2, 2PN, 2WC tầng tru...  Dự án The Vesta
# 529    Cần bán căn 2pn, 2vs toà thương mại cc The Ves...  Dự án The Vesta
# ...                                                  ...              ...
# 14888  Cần bán căn 2pn, 2vs toà thương mại cc The Ves...  Dự án The Vesta
# 14967  Cần bán căn 2pn, 2vs toà thương mại cc The Ves...  Dự án The Vesta
# 14968  Cần bán căn 2pn, 2vs toà thương mại cc The Ves...  Dự án The Vesta
# 14969  Bán căn 2PN, 2VS 1 ban công Bắc, 57m2 tòa The ...  Dự án The Vesta
# 15098  Cần bán căn 2pn, 2vs toà thương mại cc The Ves...  Dự án The Vesta
#
#                                Khu vực   Ngày đăng Ngày hết hạn    Loại tin  \
# 27     Phường Phú Lãm, Hà Đông, Hà Nội  23/02/2024   04/03/2024  Tin thường
# 86     Phường Phú Lãm, Hà Đông, Hà Nội  23/02/2024   04/03/2024  Tin thường
# 202    Phường Phú Lãm, Hà Đông, Hà Nội  23/02/2024   04/03/2024  Tin thường
# 478    Phường Phú Lãm, Hà Đông, Hà Nội  29/02/2024   10/03/2024  Tin thường
# 529    Phường Phú Lãm, Hà Đông, Hà Nội  23/02/2024   04/03/2024  Tin thường
# ...                                ...         ...          ...         ...
# 14888  Phường Phú Lãm, Hà Đông, Hà Nội  23/02/2024   04/03/2024  Tin thường
# 14967  Phường Phú Lãm, Hà Đông, Hà Nội  23/02/2024   04/03/2024  Tin thường
# 14968  Phường Phú Lãm, Hà Đông, Hà Nội  23/02/2024   04/03/2024  Tin thường
# 14969  Phường Phú Lãm, Hà Đông, Hà Nội  27/02/2024   08/03/2024  Tin thường
# 15098  Phường Phú Lãm, Hà Đông, Hà Nội  23/02/2024   04/03/2024  Tin thường
#
#          Mã tin         Người đăng  \
# 27     39051171         Hiền Alina
# 86     39051171         Hiền Alina
# 202    39051171         Hiền Alina
# 478    39196214  Ngân V3 The Vesta
# 529    39051171         Hiền Alina
# ...         ...                ...
# 14888  39051171         Hiền Alina
# 14967  39051171         Hiền Alina
# 14968  39051171         Hiền Alina
# 14969  39178033  Khanh Nguyen Quoc
# 15098  39051171         Hiền Alina
#
#                                          Thông tin mô tả Diện tích  Mức giá  \
# 27     Cần bán căn hộ 2pn, 2vs chung cư The Vesta Phú...     57 m²  2,15 tỷ
# 86     Cần bán căn hộ 2pn, 2vs chung cư The Vesta Phú...     57 m²  2,15 tỷ
# 202    Cần bán căn hộ 2pn, 2vs chung cư The Vesta Phú...     57 m²  2,15 tỷ
# 478    Gia đình cần bán gấp căn 2PN ở V3 tòa The Vest...     59 m²  2,15 tỷ
# 529    Cần bán căn hộ 2pn, 2vs chung cư The Vesta Phú...     57 m²  2,15 tỷ
# ...                                                  ...       ...      ...
# 14888  Cần bán căn hộ 2pn, 2vs chung cư The Vesta Phú...     57 m²  2,15 tỷ
# 14967  Cần bán căn hộ 2pn, 2vs chung cư The Vesta Phú...     57 m²  2,15 tỷ
# 14968  Cần bán căn hộ 2pn, 2vs chung cư The Vesta Phú...     57 m²  2,15 tỷ
# 14969  Ông bạn thân hàng xóm bận công tác dài ngày nư...     57 m²  2,05 tỷ
# 15098  Cần bán căn hộ 2pn, 2vs chung cư The Vesta Phú...     57 m²  2,15 tỷ
#
#       Hướng nhà Hướng ban công Số phòng ngủ Số toilet         Pháp lý Nội thất
# 27          Nam            Bắc      2 phòng   2 phòng             NaN   Đầy đủ
# 86          Nam            Bắc      2 phòng   2 phòng             NaN   Đầy đủ
# 202         Nam            Bắc      2 phòng   2 phòng             NaN   Đầy đủ
# 478         NaN            NaN      2 phòng   2 phòng  Sổ đỏ/ Sổ hồng   Đầy đủ
# 529         Nam            Bắc      2 phòng   2 phòng             NaN   Đầy đủ
# ...         ...            ...          ...       ...             ...      ...
# 14888       Nam            Bắc      2 phòng   2 phòng             NaN   Đầy đủ
# 14967       Nam            Bắc      2 phòng   2 phòng             NaN   Đầy đủ
# 14968       Nam            Bắc      2 phòng   2 phòng             NaN   Đầy đủ
# 14969       Nam            Bắc      2 phòng   2 phòng         Sổ hồng   Đầy đủ
# 15098       Nam            Bắc      2 phòng   2 phòng             NaN   Đầy đủ
#
# [138 rows x 17 columns]

# %% [markdown]
# Same area, same 1 building/project but may have many different units for sale

# %%
# Example of all duplicate lines "Tiêu đề" of a data sample
tieudevalue = duplicate_df["Tiêu đề"].iloc[0] # Get the value of the "Tiêu đề" column from the row at index 0 in the dataframe containing duplicates
print("Data Type =", type(tieudevalue)) # This value has a String data type
dtset.loc[dtset["Tiêu đề"] == tieudevalue] # Return to the original dataset, display all rows that are duplicates
# Out:
# Data Type = <class 'str'>
#                                                  Tiêu đề            Dự án  \
# 27     Cần bán căn 2pn, 2vs toà thương mại cc The Ves...  Dự án The Vesta
# 86     Cần bán căn 2pn, 2vs toà thương mại cc The Ves...  Dự án The Vesta
# 202    Cần bán căn 2pn, 2vs toà thương mại cc The Ves...  Dự án The Vesta
# 529    Cần bán căn 2pn, 2vs toà thương mại cc The Ves...  Dự án The Vesta
# 1122   Cần bán căn 2pn, 2vs toà thương mại cc The Ves...  Dự án The Vesta
# ...                                                  ...              ...
# 14882  Cần bán căn 2pn, 2vs toà thương mại cc The Ves...  Dự án The Vesta
# 14888  Cần bán căn 2pn, 2vs toà thương mại cc The Ves...  Dự án The Vesta
# 14967  Cần bán căn 2pn, 2vs toà thương mại cc The Ves...  Dự án The Vesta
# 14968  Cần bán căn 2pn, 2vs toà thương mại cc The Ves...  Dự án The Vesta
# 15098  Cần bán căn 2pn, 2vs toà thương mại cc The Ves...  Dự án The Vesta
#
#                                Khu vực   Ngày đăng Ngày hết hạn    Loại tin  \
# 27     Phường Phú Lãm, Hà Đông, Hà Nội  23/02/2024   04/03/2024  Tin thường
# 86     Phường Phú Lãm, Hà Đông, Hà Nội  23/02/2024   04/03/2024  Tin thường
# 202    Phường Phú Lãm, Hà Đông, Hà Nội  23/02/2024   04/03/2024  Tin thường
# 529    Phường Phú Lãm, Hà Đông, Hà Nội  23/02/2024   04/03/2024  Tin thường
# 1122   Phường Phú Lãm, Hà Đông, Hà Nội  23/02/2024   04/03/2024  Tin thường
# ...                                ...         ...          ...         ...
# 14882  Phường Phú Lãm, Hà Đông, Hà Nội  23/02/2024   04/03/2024  Tin thường
# 14888  Phường Phú Lãm, Hà Đông, Hà Nội  23/02/2024   04/03/2024  Tin thường
# 14967  Phường Phú Lãm, Hà Đông, Hà Nội  23/02/2024   04/03/2024  Tin thường
# 14968  Phường Phú Lãm, Hà Đông, Hà Nội  23/02/2024   04/03/2024  Tin thường
# 15098  Phường Phú Lãm, Hà Đông, Hà Nội  23/02/2024   04/03/2024  Tin thường
#
#          Mã tin  Người đăng  \
# 27     39051171  Hiền Alina
# 86     39051171  Hiền Alina
# 202    39051171  Hiền Alina
# 529    39051171  Hiền Alina
# 1122   39051171  Hiền Alina
# ...         ...         ...
# 14882  39051171  Hiền Alina
# 14888  39051171  Hiền Alina
# 14967  39051171  Hiền Alina
# 14968  39051171  Hiền Alina
# 15098  39051171  Hiền Alina
#
#                                          Thông tin mô tả Diện tích  Mức giá  \
# 27     Cần bán căn hộ 2pn, 2vs chung cư The Vesta Phú...     57 m²  2,15 tỷ
# 86     Cần bán căn hộ 2pn, 2vs chung cư The Vesta Phú...     57 m²  2,15 tỷ
# 202    Cần bán căn hộ 2pn, 2vs chung cư The Vesta Phú...     57 m²  2,15 tỷ
# 529    Cần bán căn hộ 2pn, 2vs chung cư The Vesta Phú...     57 m²  2,15 tỷ
# 1122   Cần bán căn hộ 2pn, 2vs chung cư The Vesta Phú...     57 m²  2,15 tỷ
# ...                                                  ...       ...      ...
# 14882  Cần bán căn hộ 2pn, 2vs chung cư The Vesta Phú...     57 m²  2,15 tỷ
# 14888  Cần bán căn hộ 2pn, 2vs chung cư The Vesta Phú...     57 m²  2,15 tỷ
# 14967  Cần bán căn hộ 2pn, 2vs chung cư The Vesta Phú...     57 m²  2,15 tỷ
# 14968  Cần bán căn hộ 2pn, 2vs chung cư The Vesta Phú...     57 m²  2,15 tỷ
# 15098  Cần bán căn hộ 2pn, 2vs chung cư The Vesta Phú...     57 m²  2,15 tỷ
#
#       Hướng nhà Hướng ban công Số phòng ngủ Số toilet Pháp lý Nội thất
# 27          Nam            Bắc      2 phòng   2 phòng     NaN   Đầy đủ
# 86          Nam            Bắc      2 phòng   2 phòng     NaN   Đầy đủ
# 202         Nam            Bắc      2 phòng   2 phòng     NaN   Đầy đủ
# 529         Nam            Bắc      2 phòng   2 phòng     NaN   Đầy đủ
# 1122        Nam            Bắc      2 phòng   2 phòng     NaN   Đầy đủ
# ...         ...            ...          ...       ...     ...      ...
# 14882       Nam            Bắc      2 phòng   2 phòng     NaN   Đầy đủ
# 14888       Nam            Bắc      2 phòng   2 phòng     NaN   Đầy đủ
# 14967       Nam            Bắc      2 phòng   2 phòng     NaN   Đầy đủ
# 14968       Nam            Bắc      2 phòng   2 phòng     NaN   Đầy đủ
# 15098       Nam            Bắc      2 phòng   2 phòng     NaN   Đầy đủ
#
# [129 rows x 17 columns]

# %% [markdown]
# "Địa chỉ"/ "Khu vực" of some stories may coincide, but "Tiêu đề" and, most importantly, "Mức giá" are not. It's normal for this template to have duplicate addresses, especially when we've dealt with the original raw data by removing some attribute columns (like Tiêu đề, Người đăng, Loại tin, Mã tin) and adjusting the "Số phòng ngủ", "Số tầng", "Số toliet", etc. so that they are not NaN, empty or Missing.

# %%
# Except for the original row, remove all subsequent rows that are duplicates:
print("Initial dataset size:", dtset.shape)
dtset = dtset.drop_duplicates()
dtset = dtset.reset_index(drop=True)
print("Size after removing duplicate rows:", dtset.shape)
# Out:
# Initial dataset size: (15145, 17)
# Size after removing duplicate rows: (14990, 17)

# %% [markdown]
# There exist lines with the same 'Mã tin' but different 'Ngày đăng' and 'Ngày hết hạn', making them separate home sale listings. Therefore, we must check the duplicate again and delete the messages with the same 'Mã tin'.

# %%
# Check for duplicate again and delete messages with the same "Mã tin"
# Check the property listings with the same "Mã tin"
matin_duplicate_df = dtset[dtset["Mã tin"].duplicated()]
print("Rows with similar Mã tin:", len(matin_duplicate_df))
matin_duplicate_df.head(3)
# Out:
# Rows with similar Mã tin: 25
#                                                 Tiêu đề  \
# 1299  BQL Dolphin Plaza mở bán những căn hộ mua thẳn...
# 2808  Chính chủ bán căn hộ studio 34m2. Phân khu mới...
# 2916  Tổng hợp quỹ căn Stu,1-3N View đẹp giá rẻ cắt ...
#
#                                   Dự án  \
# 1299                Dự án Dolphin Plaza
# 2808                    Dự án The Miami
# 2916  Dự án Vinhomes Ocean Park Gia Lâm
#
#                                                 Khu vực   Ngày đăng  \
# 1299  Phố Trần Bình, Phường Mỹ Đình 2, Nam Từ Liêm, ...  28/02/2024
# 2808                Phường Tây Mỗ, Nam Từ Liêm, Hà Nội.  29/02/2024
# 2916                       Xã Dương Xá, Gia Lâm, Hà Nội  05/03/2024
#
#      Ngày hết hạn           Loại tin    Mã tin          Người đăng  \
# 1299   09/03/2024         Tin thường  38593119         Ban Quản Lý
# 2808   15/03/2024         Tin thường  38241208  Hồ Phương Vinhomes
# 2916   20/03/2024  Tin VIP Kim Cương  39114589    Yến Hoa Vinhomes
#
#                                         Thông tin mô tả Diện tích  \
# 1299  Thị trường Dolphin Plaza chưa bao giờ hết sôi ...    133 m²
# 2808  Chính chủ bán căn hộ Studio 34m². Phân khu mới...     34 m²
# 2916  Bên em đang có quỹ căn chuyển nhượng giá siêu ...     59 m²
#
#             Mức giá  Hướng nhà Hướng ban công Số phòng ngủ Số toilet  \
# 1299  35,6 triệu/m²        Bắc            Nam      2 phòng   3 phòng
# 2808        1,68 tỷ  Tây - Nam     Đông - Bắc      1 phòng   1 phòng
# 2916        1,75 tỷ        NaN            NaN      2 phòng   1 phòng
#
#               Pháp lý Nội thất
# 1299            Sổ đỏ     Full
# 2808              NaN   Cơ bản
# 2916  Sổ đỏ/ Sổ hồng.      NaN

# %%
# Example of all rows with duplicate "Mã tin" for a sample data
matinvalue = matin_duplicate_df["Mã tin"].iloc[0] # Get the value of "Mã tin" from the row at index 0 in the dataframe containing duplicates
print("Data Type =", type(matinvalue)) # This value has an integer data type
dtset.loc[dtset["Mã tin"] == matinvalue] # Return to the original dataset, display all rows with the same "Mã tin"
# Out:
# Data Type = <class 'numpy.int64'>
#                                                 Tiêu đề                Dự án  \
# 57    BQL Dolphin Plaza mở bán những căn hộ mua thẳn...  Dự án Dolphin Plaza
# 1299  BQL Dolphin Plaza mở bán những căn hộ mua thẳn...  Dự án Dolphin Plaza
#
#                                                 Khu vực   Ngày đăng  \
# 57    Phố Trần Bình, Phường Mỹ Đình 2, Nam Từ Liêm, ...  28/02/2024
# 1299  Phố Trần Bình, Phường Mỹ Đình 2, Nam Từ Liêm, ...  28/02/2024
#
#      Ngày hết hạn           Loại tin    Mã tin   Người đăng  \
# 57     09/03/2024  Tin VIP Kim Cương  38593119  Ban Quản Lý
# 1299   09/03/2024         Tin thường  38593119  Ban Quản Lý
#
#                                         Thông tin mô tả Diện tích  \
# 57    Thị trường Dolphin Plaza chưa bao giờ hết sôi ...    133 m²
# 1299  Thị trường Dolphin Plaza chưa bao giờ hết sôi ...    133 m²
#
#             Mức giá Hướng nhà Hướng ban công Số phòng ngủ Số toilet Pháp lý  \
# 57    35,6 triệu/m²       Bắc            Nam      2 phòng   3 phòng   Sổ đỏ
# 1299  35,6 triệu/m²       Bắc            Nam      2 phòng   3 phòng   Sổ đỏ
#
#      Nội thất
# 57       Full
# 1299     Full

# %%
MaTin_Index_ToDelete = [] # Create a list variable to store the indices of these duplicates
for ind in matin_duplicate_df.index:
  MaTin_Index_ToDelete.append(ind)
print("Index Count =", len(MaTin_Index_ToDelete))
print("Index List:", MaTin_Index_ToDelete) # From this list variable, we can return to the original dataset to delete
# rows starting from the second occurrence that have the same "Mã tin" as the first occurrence
# Out:
# Index Count = 25
# Index List: [1299, 2808, 2916, 3440, 4779, 5057, 5454, 6016, 6115, 6816, 7067, 7150, 7305, 8121, 8518, 8738, 9632, 11050, 11061, 12058, 13550, 13621, 14040, 14321, 14923]

# %%
print("Initial dataset size:", dtset.shape)
for ind in MaTin_Index_ToDelete:
  dtset = dtset.drop(ind)
dtset = dtset.reset_index(drop=True)
print("Size after removing duplicate rows:", dtset.shape)
# Out:
# Initial dataset size: (14990, 17)
# Size after removing duplicate rows: (14965, 17)

# %% [markdown]
# ###  Attribute columns

# %% [markdown]
# Missing Data

# %%
print("Dataset shape:", dtset.shape)
# Out:
# Dataset shape: (14965, 17)

# %%
# Check the number of missing values in each column as a percentage:
missing_percentage = dtset.isnull().sum() / dtset.shape[0] * 100.00
missing_percentage
# Out:
# Tiêu đề             0.000000
# Dự án               0.000000
# Khu vực             0.000000
# Ngày đăng           0.000000
# Ngày hết hạn        0.000000
# Loại tin            0.000000
# Mã tin              0.000000
# Người đăng          0.000000
# Thông tin mô tả     0.000000
# Diện tích           0.000000
# Mức giá             0.000000
# Hướng nhà          50.845306
# Hướng ban công     46.194454
# Số phòng ngủ        2.953558
# Số toilet           7.878383
# Pháp lý            19.445373
# Nội thất           26.361510
# dtype: float64

# %%
# Check unique column "Pháp lý"
phaply = dtset["Pháp lý"].copy()
phaply_UniqueCount = phaply.value_counts()
print(phaply_UniqueCount)
# Out:
# Pháp lý
# Sổ đỏ/ Sổ hồng                                                                                                                                                                                         8400
# Hợp đồng mua bán                                                                                                                                                                                       1257
# Sổ đỏ/ Sổ hồng.                                                                                                                                                                                         749
# Sổ đỏ                                                                                                                                                                                                   551
# Đang chờ sổ                                                                                                                                                                                             174
#                                                                                                                                                                                                        ...
# Pháp lý rõ ràng                                                                                                                                                                                           1
# Pháp lý dự án minh bạch, khách hàng xem trực tiếp hồ sơ pháp lý tại văn phòng Chủ Đầu Tư. Khách hàng mua bán bằng hình thức kí Hợp Đồng Mua Bán nhà ở hình thành trong tương lai trực tiếp với CĐT.       1
# Sổ đỏ trao tay                                                                                                                                                                                            1
# Pháp lý minh bạch, khách hàng có nhu cầu xem pháp lý dự án xem trực tiếp tại văn phòng chủ đầu tư. Khách hàng kí trực tiếp hợp đồng mua bán nhà hình thành trong tương lai với CĐT.                       1
# Sỏ đỏ                                                                                                                                                                                                     1
# Name: count, Length: 140, dtype: int64

# %% [markdown]
# As for "Pháp lý", this is information that the seller or broker selling the house freely declares, has no specific rules, presents content that is not related to papers or even does not declare anything. Because the values of "Legal" are quite diverse with nearly 140 unique values and complex data processing with  "Vi bằng", "Hợp đồng mua bán", "Hợp đồng đặt cọc", "Giấy tay", "Sổ hồng" hay "Sổ đỏ" all have separate legal meanings.

# %% [markdown]
# ### Format number

# %% [markdown]
# Create a new DataFrame 'df' as a copy of the original DataFrame 'dtset'

# %%
# Create a new DataFrame 'df' as a copy of the original DataFrame 'dtset'
df = dtset.loc[:, :].copy()

# %%
# Function to convert "Ngày đăng" and "Ngày hết hạn"
def convert_dates(df):
    df['Ngày đăng'] = pd.to_datetime(df['Ngày đăng'], format='%d/%m/%Y')
    df['Ngày hết hạn'] = pd.to_datetime(df['Ngày hết hạn'], format='%d/%m/%Y')
    return df

# Assuming df is your DataFrame
df = convert_dates(df)

# %%
# Function to extract area from 'Diện tích' column and convert it to float
def get_area(dientich):
    space_index = dientich.find(' ')
    area = dientich[:space_index].strip()  # Extract numerical part
    area = area.replace(',', '.')          # Replace comma with dot for decimal handling
    return float(area)

# Function to format prices in 'Mức giá' column and return as float
def format_price(x):
    result = x['Mức giá']  # Extract price value
    area = x['Diện tích']  # Extract area value for per square meter price calculation
    
    result = result.replace(',', '.')  # Replace comma with dot for decimal handling
    
    # Price formatting based on suffix ('triệu/m²', 'triệu', 'tỷ')
    if 'triệu/m²' in result:
        # Convert to float and round to one decimal place for 'triệu/m²' prices
        return round(float(result.replace(' triệu/m²', '')), 1)
    elif 'triệu' in result:
        # Convert to float and adjust for area if necessary, rounding to one decimal place
        return round(float(result.replace(' triệu', '')) / area, 1)
    elif 'tỷ' in result:
        # Convert to float, adjust for area if necessary, and convert to mill, rounding to one decimal place
        return round(float(result.replace(' tỷ', '')) * 1000 / area, 1)
    else:
        # If blank, 'Thỏa thuận', or NaN
        return result

# Function to convert 'Số phòng ngủ' and 'Số toilet' values to int
def convert_to_int(room):
    if isinstance(room, str) and 'phòng' in room:
        return int(room.replace(' phòng', ''))
    else:
        return np.nan

# Applying get_area function to the 'Diện tích' column
df['Diện tích'] = df['Diện tích'].apply(get_area)

# Applying format_price function to the 'Mức giá' column
df['Mức giá'] = df.apply(format_price, axis=1)

# Applying convert_to_int function to the 'Số phòng ngủ' and 'Số toilet' columns
df['Số phòng ngủ'] = df['Số phòng ngủ'].apply(convert_to_int)
df['Số toilet'] = df['Số toilet'].apply(convert_to_int)

df.head(3)
# Out:
#                                              Tiêu đề  \
# 0  Chính chủ bán căn hoa hậu view thoáng tầng tru...
# 1                    Bán căn hộ CT5 Văn Khê, Hà Đông
# 2  Cần tiền bán nhanh căn hộ cao cấp tòa Diamond ...
#
#                         Dự án  \
# 0         Dự án Golden Palace
# 1           Dự án CT5 Văn Khê
# 2  Dự án Diamond Flower Tower
#
#                                              Khu vực  Ngày đăng Ngày hết hạn  \
# 0  đường Mễ Trì, Phường Mễ Trì, Nam Từ Liêm, Hà Nội. 2024-02-26   2024-03-07
# 1                     Phường La Khê, Hà Đông, Hà Nội 2024-02-26   2024-03-07
# 2  Phố Hoàng Đạo Thúy, Phường Nhân Chính, Thanh X... 2024-02-21   2024-03-02
#
#      Loại tin    Mã tin      Người đăng  \
# 0  Tin thường  37587338  Phạm Quang Huy
# 1  Tin thường  39014297  Little Bigbang
# 2  Tin thường  39135117         Em Thúy
#
#                                      Thông tin mô tả  Diện tích Mức giá  \
# 0  Chính chủ bán căn hoa hậu view thoáng tầng tru...      128.0    35.0
# 1  Bán căn hộ CT5A, Văn Khê, Hà Đông.\n- Diện tíc...       82.0    32.3
# 2  - Chính chủ cần tiền đầu tư nhờ bán gấp căn hộ...      115.0    55.0
#
#    Hướng nhà Hướng ban công  Số phòng ngủ  Số toilet         Pháp lý Nội thất
# 0  Tây - Bắc     Đông - Nam           3.0        2.0             NaN      NaN
# 1  Tây - Bắc     Đông - Nam           2.0        2.0         Sổ hồng   Đầy đủ
# 2        Nam            NaN           3.0        2.0  Sổ đỏ/ Sổ hồng   Đầy đủ

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14965 entries, 0 to 14964
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Tiêu đề          14965 non-null  object
#  1   Dự án            14965 non-null  object
#  2   Khu vực          14965 non-null  object
#  3   Ngày đăng        14965 non-null  datetime64[ns]
#  4   Ngày hết hạn     14965 non-null  datetime64[ns]
#  5   Loại tin         14965 non-null  object
#  6   Mã tin           14965 non-null  int64
#  7   Người đăng       14965 non-null  object
#  8   Thông tin mô tả  14965 non-null  object
#  9   Diện tích        14965 non-null  float64
#  10  Mức giá          14965 non-null  object
#  11  Hướng nhà        7356 non-null   object
#  12  Hướng ban công   8052 non-null   object
#  13  Số phòng ngủ     14523 non-null  float64
#  14  Số toilet        13786 non-null  float64
#  15  Pháp lý          12055 non-null  object
#  16  Nội thất         11020 non-null  object
# dtypes: datetime64[ns](2), float64(3), int64(1), object(11)
# memory usage: 1.9+ MB

# %%
# The original dataset
print(dtset.shape)
dtset.head(3)
# Out:
# (14965, 17)
#                                              Tiêu đề  \
# 0  Chính chủ bán căn hoa hậu view thoáng tầng tru...
# 1                    Bán căn hộ CT5 Văn Khê, Hà Đông
# 2  Cần tiền bán nhanh căn hộ cao cấp tòa Diamond ...
#
#                         Dự án  \
# 0         Dự án Golden Palace
# 1           Dự án CT5 Văn Khê
# 2  Dự án Diamond Flower Tower
#
#                                              Khu vực   Ngày đăng Ngày hết hạn  \
# 0  đường Mễ Trì, Phường Mễ Trì, Nam Từ Liêm, Hà Nội.  26/02/2024   07/03/2024
# 1                     Phường La Khê, Hà Đông, Hà Nội  26/02/2024   07/03/2024
# 2  Phố Hoàng Đạo Thúy, Phường Nhân Chính, Thanh X...  21/02/2024   02/03/2024
#
#      Loại tin    Mã tin      Người đăng  \
# 0  Tin thường  37587338  Phạm Quang Huy
# 1  Tin thường  39014297  Little Bigbang
# 2  Tin thường  39135117         Em Thúy
#
#                                      Thông tin mô tả Diện tích      Mức giá  \
# 0  Chính chủ bán căn hoa hậu view thoáng tầng tru...    128 m²  35 triệu/m²
# 1  Bán căn hộ CT5A, Văn Khê, Hà Đông.\n- Diện tíc...     82 m²      2,65 tỷ
# 2  - Chính chủ cần tiền đầu tư nhờ bán gấp căn hộ...    115 m²  55 triệu/m²
#
#    Hướng nhà Hướng ban công Số phòng ngủ Số toilet         Pháp lý Nội thất
# 0  Tây - Bắc     Đông - Nam      3 phòng   2 phòng             NaN      NaN
# 1  Tây - Bắc     Đông - Nam      2 phòng   2 phòng         Sổ hồng   Đầy đủ
# 2        Nam            NaN      3 phòng   2 phòng  Sổ đỏ/ Sổ hồng   Đầy đủ

# %%
df
# Out:
#                                                  Tiêu đề  \
# 0      Chính chủ bán căn hoa hậu view thoáng tầng tru...
# 1                        Bán căn hộ CT5 Văn Khê, Hà Đông
# 2      Cần tiền bán nhanh căn hộ cao cấp tòa Diamond ...
# 3      Bán căn hộ Duplex Sun Grand City - 69B Thụy Kh...
# 4      Bán căn hộ chung cư Vinhomes West Point. 3PN 9...
# ...                                                  ...
# 14960  Mở bán chung cư mini Hoàng Mai - Minh Khai 46 ...
# 14961  Gia đình cần nhượng lại CHCC 6th Element - 2 p...
# 14962  Nhà tôi muốn đổi sang căn 3N nên muốn bán lại ...
# 14963  Bán căn 83m2 - 2PN sáng - Times City - Giá 4.6 tỷ
# 14964  Bán căn 3 ngủ - 2 ban công 100m2 Sunshine Rive...
#
#                             Dự án  \
# 0             Dự án Golden Palace
# 1               Dự án CT5 Văn Khê
# 2      Dự án Diamond Flower Tower
# 3                  Sun Grand City
# 4       Dự án Vinhomes West Point
# ...                           ...
# 14960             Đường Minh Khai
# 14961           Dự án 6th Element
# 14962   Dự án Vinhomes D'Capitale
# 14963            Dự án Times City
# 14964    Dự án Sunshine Riverside
#
#                                                  Khu vực  Ngày đăng  \
# 0      đường Mễ Trì, Phường Mễ Trì, Nam Từ Liêm, Hà Nội. 2024-02-26
# 1                         Phường La Khê, Hà Đông, Hà Nội 2024-02-26
# 2      Phố Hoàng Đạo Thúy, Phường Nhân Chính, Thanh X... 2024-02-21
# 3      69B, Đường Thụy Khuê, Phường Thụy Khuê, Tây Hồ... 2024-02-26
# 4      Đường Phạm Hùng, Phường Mễ Trì, Nam Từ Liêm, H... 2024-02-25
# ...                                                  ...        ...
# 14960                 Phường Mai Động, Hoàng Mai, Hà Nội 2024-03-01
# 14961                     Phường Xuân La, Tây Hồ, Hà Nội 2024-02-27
# 14962  Đường Trần Duy Hưng, Phường Trung Hòa, Cầu Giấ... 2024-03-09
# 14963  Đường Minh Khai, Phường Vĩnh Tuy, Hai Bà Trưn... 2024-02-26
# 14964                  Phường Phú Thượng, Tây Hồ, Hà Nội 2024-03-10
#
#       Ngày hết hạn    Loại tin    Mã tin           Người đăng  \
# 0       2024-03-07  Tin thường  37587338       Phạm Quang Huy
# 1       2024-03-07  Tin thường  39014297       Little Bigbang
# 2       2024-03-02  Tin thường  39135117              Em Thúy
# 3       2024-03-07  Tin thường  37509440               Le Yen
# 4       2024-03-06  Tin thường  39159735             Vũ Thịnh
# ...            ...         ...       ...                  ...
# 14960   2024-03-11  Tin thường  39206578  Chủ Đầu Tư Mai Hồng
# 14961   2024-03-08  Tin thường  39178538            Hdhome ☘️
# 14962   2024-03-19  Tin thường  39183034  Nguyễn Thị Ngọc Anh
# 14963   2024-03-07  Tin thường  36361390          Huyền Huyền
# 14964   2024-03-20  Tin thường  39173497                Lý Vt
#
#                                          Thông tin mô tả  Diện tích  \
# 0      Chính chủ bán căn hoa hậu view thoáng tầng tru...      128.0
# 1      Bán căn hộ CT5A, Văn Khê, Hà Đông.\n- Diện tíc...       82.0
# 2      - Chính chủ cần tiền đầu tư nhờ bán gấp căn hộ...      115.0
# 3      Cần bán căn hộ Duplex cao cấp - Sun Grand City...      250.0
# 4      Bán căn hộ chung cư Vinhomes West Point.\nCăn ...       93.0
# ...                                                  ...        ...
# 14960  Mở bán chung cư mini Hoàng Mai - Minh Khai.\nV...       50.0
# 14961  Do nhu cầu không sử dụng gia đình cần bán lại ...       82.4
# 14962  Nhà tôi muốn đổi sang căn 3N nên muốn bán lại ...       73.0
# 14963  Bán căn 83m² - 2PN sáng - Times City - Giá 4.6...       83.0
# 14964  Cần bán căn hộ 3 ngủ Sunshine Riverside Tây Hồ...      100.0
#
#           Mức giá  Hướng nhà Hướng ban công  Số phòng ngủ  Số toilet  \
# 0            35.0  Tây - Bắc     Đông - Nam           3.0        2.0
# 1            32.3  Tây - Bắc     Đông - Nam           2.0        2.0
# 2            55.0        Nam            NaN           3.0        2.0
# 3            96.0        NaN            NaN           4.0        3.0
# 4            69.9  Tây - Bắc     Đông - Nam           3.0        2.0
# ...           ...        ...            ...           ...        ...
# 14960  Thỏa thuận        NaN            NaN           2.0        1.0
# 14961  Thỏa thuận        NaN           Đông           2.0        NaN
# 14962        68.5  Tây - Bắc     Đông - Nam           2.0        2.0
# 14963        55.4        Nam            Nam           2.0        2.0
# 14964        55.0        NaN           Đông           3.0        3.0
#
#               Pháp lý Nội thất
# 0                 NaN      NaN
# 1             Sổ hồng   Đầy đủ
# 2      Sổ đỏ/ Sổ hồng   Đầy đủ
# 3                 NaN      NaN
# 4      Sổ đỏ/ Sổ hồng   Cơ bản
# ...               ...      ...
# 14960  Sổ đỏ/ Sổ hồng   Cơ bản
# 14961             NaN      NaN
# 14962  Sổ đỏ/ Sổ hồng   Đầy đủ
# 14963  Sổ đỏ/ Sổ hồng   Cơ bản
# 14964  Sổ đỏ/ Sổ hồng   Cơ bản
#
# [14965 rows x 17 columns]

# %%
# Save the DataFrame to a CSV file 
df.to_csv('chungcu_clean.csv', index=False)
